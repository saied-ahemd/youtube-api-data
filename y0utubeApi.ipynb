# %%
import requests
import pandas as pd
import time

# %%
api_key  = 'AIzaSyAVZgubr8S85ms9d12X_1XZJ5EJ_3o3hWo'
chnanel_id = 'UCwgViahZ-mI0MVZ7iRbB2kw'
ch = 'UCW8Ews7tdKKkBT6GdtQaXvQ'

# %%
def get_video_details(video_id):

    #collecting view, like, dislike, comment counts
    url_video_stats = f'https://www.googleapis.com/youtube/v3/videos?id={video_id}&part=statistics&key={api_key}'
    response_video_stats = requests.get(url_video_stats).json()
    view_count = response_video_stats['items'][0]['statistics']['viewCount']
    like_count = response_video_stats['items'][0]['statistics']['likeCount']
    dislike_count = response_video_stats['items'][0]['statistics']['dislikeCount']
    comment_count = response_video_stats['items'][0]['statistics']['commentCount']

    return view_count, like_count, dislike_count, comment_count

# %%
# make a loop to get the important info
def get_vidoes(df):
    pageToken = ''
    url= f'https://www.googleapis.com/youtube/v3/search?key={api_key}&channelId={ch}&part=snippet,id&order=date&maxResults=10000&{pageToken}'
    respode  = requests.get(url=url).json()
    # make the loop sleep for 1 second before start to get the data
    time.sleep(1)

    for vidoe in respode['items']:
        if vidoe['id']['kind']=='youtube#video':
            vidoe_id = vidoe['id']['videoId']
            date = vidoe['snippet']['publishedAt']
            date = str(date).split('T')[0]
            title = vidoe['snippet']['title']
            description = vidoe['snippet']['description']

            # i need to get the like count and dislike count so i need to make another api call
            view_count, like_count, dislike_count, comment_count = get_video_details(vidoe_id)
            
            df = df.append({'video_id':vidoe_id,'video_title':title,
                                    "upload_date":date,"description": description,"view_count":view_count,
                                    "like_count":like_count,"dislike_count":dislike_count,
                                    "comment_count":comment_count},ignore_index=True)
                                    
    return df

# %%
#main

#build our dataframe
df2 = pd.DataFrame(columns=["video_id","video_title","upload_date","description","view_count","like_count","dislike_count","comment_count"]) 

df2 = get_vidoes(df2)
df2
# Out:
#        video_id                                        video_title  \
# 0   Bgpp99iz0I0  Most Common Coding Mistakes on Data Science In...
# 1   GeJUvdkJKEc  Multiple Solutions to Data Scientist Interview...
# 2   GGURenNfXI0  Multiple Approaches for Solving a Twitter Data...
# 3   PlpUo6bHsBQ  Advanced Facebook Data Science SQL interview q...
# 4   uY2wfR8Dkqo     5 Tips for a Successful Data Science Interview
# 5   yY7yau9j3xk  Data Science SQL Scenario Based Interview Ques...
# 6   i-E4pdU2qXM  Data Science SQL Interview Question Walkthroug...
# 7   T1UhSuKqy3A  Most Common Data Science SQL Interview Questio...
# 8   2iE3JgNTwVU  A Walkthrough of Data Science SQL Interview Qu...
# 9   RgKMbpEylWA  Comparing FAANG vs Non-FAANG Data Science Inte...
# 10  giGIPINLqJs  An Analysis of 900 Data Science Interview Ques...
# 11  77IVf0zgmwI  Importing a Pandas Dataframe to a Database in ...
# 12  xtbMCAVXDmU  Facebook and Microsoft Data Science SQL interv...
# ...
