# %%
import requests
import pandas as pd
import time

# %%
api_key  = 'AIzaSyAVZgubr8S85ms9d12X_1XZJ5EJ_3o3hWo'
chnanel_id = 'UCwgViahZ-mI0MVZ7iRbB2kw'
ch = 'UCW8Ews7tdKKkBT6GdtQaXvQ'

# %%
# make the api call
# https://www.googleapis.com/youtube/v3/search?key="+API_KEY+"&channelId="+CHANNEL_ID+"&part=snippet,id&order=date&maxResults=10000&"+pageToken
pageToken = ''
url= f'https://www.googleapis.com/youtube/v3/search?key={api_key}&channelId={ch}&part=snippet,id&order=date&maxResults=10000&{pageToken}'
res  = requests.get(url=url).json()

# %%
res
# Out:
# {'kind': 'youtube#searchListResponse',
#  'etag': 'IV38eT1OHsLeabqzMcbQSuBRCYw',
#  'nextPageToken': 'CDIQAA',
#  'regionCode': 'EG',
#  'pageInfo': {'totalResults': 83, 'resultsPerPage': 50},
#  'items': [{'kind': 'youtube#searchResult',
#    'etag': 'vP7cBCio4ERjH7qZ9RFvKJ-71yE',
#    'id': {'kind': 'youtube#video', 'videoId': 'Bgpp99iz0I0'},
#    'snippet': {'publishedAt': '2021-11-04T01:53:13Z',
#     'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#     'title': 'Most Common Coding Mistakes on Data Science Interviews',
#     'description': 'In this video, we will see the most common coding mistakes candidates make when answering SQL questions during their interviews and also the ways in which ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Bgpp99iz0I0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Bgpp99iz0I0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
# ...
